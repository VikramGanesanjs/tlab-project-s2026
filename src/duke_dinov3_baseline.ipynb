# %%
import pydicom
import matplotlib.pyplot as plt

# %%
path_to_dcm = '/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri/Breast_MRI_001/1.3.6.1.4.1.14519.5.2.1.186051521067863971269584893740842397538/MR_1.3.6.1.4.1.14519.5.2.1.299258169800035493747271591938205747500/0e15c399-4fef-40e8-8880-7f76c93646d1.dcm'

ds = pydicom.dcmread(path_to_dcm)

# %%
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 204
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Segmentation Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7230010.3.1.4.17436516.3900769.1714669375.526334
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
# (0002,0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['DERIVED', 'PRIMARY']
# (0008,0016) SOP Class UID                       UI: Segmentation Storage
# (0008,0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.17436516.3900769.1714669375.526334
# ...

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
plt.show()

# %%
import pandas as pd

df = pd.read_excel('/common/ganesanv/tlab/data/duke/Breast-Cancer-MRI-filepath_filename-mapping.xlsx')
df.head()
# Out:
#                                     sop_instance_UID  \
# 0  1.3.6.1.4.1.14519.5.2.1.1805789812895034139917...
# 1  1.3.6.1.4.1.14519.5.2.1.4903237729147735321973...
# 2  1.3.6.1.4.1.14519.5.2.1.3061160038794820079325...
# 3  1.3.6.1.4.1.14519.5.2.1.1574717199045785031549...
# 4  1.3.6.1.4.1.14519.5.2.1.2594404476894572978078...
#
#                           original_path_and_filename  \
# 0  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 1  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 2  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 3  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 4  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
#
#                                         classic_path  \
# 0  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 1  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 2  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 3  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# ...

# %%
df.columns
# Out:
# Index(['sop_instance_UID', 'original_path_and_filename', 'classic_path',
#        'descriptive_path', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'series_sort'],
#       dtype='object')

# %%
import os

len(os.listdir('/common/ganesanv/tlab/data/duke/duke_breast_cancer_mri/Breast_MRI_005/1.3.6.1.4.1.14519.5.2.1.186051521067863971269584893740842397538/MR_1.3.6.1.4.1.14519.5.2.1.36132446009921188007040304109146192755'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 import os
# ----> 3 len(os.listdir('/common/ganesanv/tlab/data/duke/duke_breast_cancer_mri/Breast_MRI_005/1.3.6.1.4.1.14519.5.2.1.186051521067863971269584893740842397538/MR_1.3.6.1.4.1.14519.5.2.1.36132446009921188007040304109146192755'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/common/ganesanv/tlab/data/duke/duke_breast_cancer_mri/Breast_MRI_005/1.3.6.1.4.1.14519.5.2.1.186051521067863971269584893740842397538/MR_1.3.6.1.4.1.14519.5.2.1.36132446009921188007040304109146192755'

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
import nibabel as nib

import numpy as np

# %%
full = nib.load('/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri_nifti/Breast_MRI_127/post_1/volume.nii')
left = nib.load('/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri_nifti/Breast_MRI_127/post_1/left.nii')
right = nib.load('/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri_nifti/Breast_MRI_127/post_1/right.nii')

full_data = full.get_fdata()
left_data = left.get_fdata()
right_data = right.get_fdata()

# %%
p2 = '/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri/Breast_MRI_002/1.3.6.1.4.1.14519.5.2.1.29344851079648912610491979642001151972/MR_1.3.6.1.4.1.14519.5.2.1.92459963600394245252521533321918466447/0bcce30a-133d-4c53-a53e-3bdd0fef8471.dcm'
a = pydicom.dcmread(p2)
plt.imshow(a.pixel_array, cmap=plt.cm.bone)
plt.show()
print(a)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 202
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.93994274500455187886474171207692097222
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002,0013) Implementation Version Name         SH: '0.5'
# (0002,0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008,0012) Instance Creation Date              DA: '19900101'
# (0008,0016) SOP Class UID                       UI: MR Image Storage
# ...

# %%
p3 = '/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri/Breast_MRI_127/1.3.6.1.4.1.14519.5.2.1.266059881053165504473473571293999455482/MR_1.3.6.1.4.1.14519.5.2.1.105509649724764351106914687948025550979/02b2c9b7-9cba-4041-893b-1b6b9cc9c05c.dcm'
b = pydicom.dcmread(p3)
plt.imshow(b.pixel_array, cmap=plt.cm.bone)
plt.show()
print(b)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 202
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.40288129622933582873227395405670511380
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002,0013) Implementation Version Name         SH: '0.5'
# (0002,0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND']
# (0008,0012) Instance Creation Date              DA: '19900101'
# (0008,0013) Instance Creation Time              TM: '073625.109000'
# ...

# %%
masks2 = nib.load('/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri/Breast_MRI_127/1.3.6.1.4.1.14519.5.2.1.266059881053165504473473571293999455482/MR_1.3.6.1.4.1.14519.5.2.1.105509649724764351106914687948025550979/breast_divider.nii.gz')

plt.imshow(masks2.get_fdata()[:, :, 80], cmap=plt.cm.bone)
plt.show()

# %%
full_data.shape
# Out:
# (512, 512, 142)

# %%
plt.imshow(full_data[:, :, 80], cmap=plt.cm.bone)
plt.show()

plt.imshow(left_data[:, :, 80], cmap=plt.cm.bone)
plt.show()

plt.imshow(right_data[:, :, 80], cmap=plt.cm.bone)
plt.show()

# %%
masks = nib.load('/common/ganesanv/tlab/data/tcia/duke_breast_cancer_mri/Breast_MRI_001/1.3.6.1.4.1.14519.5.2.1.186051521067863971269584893740842397538/MR_1.3.6.1.4.1.14519.5.2.1.15147203499230039585785258602759759529/breast_divider.nii.gz')

# %%
m = masks.get_fdata()
m.shape
# Out:
# (448, 448, 160)

# %%
plt.imshow(m[:, :, 80], cmap=plt.cm.bone)
