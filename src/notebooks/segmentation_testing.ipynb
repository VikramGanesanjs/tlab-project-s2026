# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# %%
image = nib.load('/common/ganesanv/tlab/data/nnUNet_raw/Dataset001_AMOS22/imagesTr/amos_0001.nii.gz')

# %%
image.get_fdata()
# Out:
# array([[[-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         ...,
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.]],
#
#        [[-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         ...,
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.]],
#
#        [[-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#         [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
# ...
