# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dp = np.load('/common/ganesanv/tlab/data/breastdm/cls/LBP/img17Se/train/Benign/BreaDM-Be-1801/p-032.npy', allow_pickle=True)

# %%
dp2 = np.load('/common/ganesanv/tlab/data/breastdm/seg3D/train/images/BreaDM-Be-1817/SUB2.npy')

# %%
dp2.shape
# Out:
# (369, 369, 8)

# %%
plt.imshow(dp2[:, :, 4], cmap=plt.cm.bone)

# %%
from pathlib import Path

base_path = Path('/common/ganesanv/tlab/data/breastdm/seg3D/train/images')

shapes = []

globbed = base_path.glob('BreaDM-*')

for p in list(globbed):
    shapes.append(np.load(p / 'SUB2.npy').shape)

# %%
print(shapes)
# Out:
# [(369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 369, 8), (369, 3
# ...

# %%
print(np.unique(shapes))
# Out:
# [  8 369]
